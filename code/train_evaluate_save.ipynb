# %%
import joblib

# %%
eval=joblib.load('../evaluations/mnist_svc_evaluation.pkl')

# %%
eval.show()
# Out:
# Point estimation for accuracy (test set): 0.9655
# 95 % confidence interval for accuracy: (0.9653308481398222,0.9657558185268447)

# %%
eval.df.sort_values(by='rank_test_score').head()
# Out:
#    param_svc__C param_svc__gamma param_svc__degree param_svc__kernel  \
# 36     1.505435         0.000619                 2               rbf
# 37     2.527287         0.000312                 1               rbf
# 31      0.86692         0.000859                 1               rbf
# 33    23.054155         0.000043                 1               rbf
# 38     0.001189         0.000158                 3            linear
#
#     mean_test_score  std_test_score  rank_test_score
# 36           0.7980        0.011815                1
# 37           0.7976        0.011569                2
# 31           0.7908        0.011957                3
# 33           0.7870        0.010060                4
# 38           0.7866        0.011395                5

# %%
eval=joblib.load('../evaluations/mnist_rf_evaluation.pkl')

# %%
eval.show()
# Out:
# Point estimation for accuracy (test set): 0.9581
# 95 % confidence interval for accuracy: (0.957853508804896,0.9582951578617703)

# %%
eval.df.sort_values(by='rank_test_score').head()
# Out:
#    param_rf__max_depth param_rf__max_features param_rf__max_samples  \
# 40                  16                   log2                   1.0
# 15                  16                   sqrt                   1.0
# 38                  15                   log2                   1.0
# 33                  15                   log2              0.822214
# 41                  16                   log2                   1.0
#
#    param_rf__min_samples_leaf param_rf__min_samples_split  \
# 40                          1                           2
# 15                          1                           2
# 38                          1                           2
# 33                          1                           2
# 41                          1                           2
#
#    param_rf__n_estimators  mean_test_score  std_test_score  rank_test_score
# 40                   1000           0.8402        0.013497                1
# ...

# %%
eval=joblib.load('../evaluations/mnist_cnn_evaluation.pkl')

# %%
eval.show()
# Out:
# Point estimation for accuracy (test set): 0.9793
# 95 % confidence interval for accuracy: (0.9790672388788553,0.9794187611211447)
